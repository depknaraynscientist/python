# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Guessing Game Challenge
#
# Let's use `while` loops to create a guessing game.
#
# The Challenge:
#
# Write a program that picks a random integer from 1 to 100, and has players guess the number. The rules are:
#
# 1. If a player's guess is less than 1 or greater than 100, say "OUT OF BOUNDS"
# 2. On a player's first turn, if their guess is
#  * within 10 of the number, return "WARM!"
#  * further than 10 away from the number, return "COLD!"
# 3. On all subsequent turns, if a guess is
#  * closer to the number than the previous guess return "WARMER!"
#  * farther from the number than the previous guess, return "COLDER!"
# 4. When the player's guess equals the number, tell them they've guessed correctly *and* how many guesses it took!
#
# You can try this from scratch, or follow the steps outlined below. A separate Solution notebook has been provided. Good luck!

# %%
from random import randint, random

# %%
number = randint(1,100)
number
# Out:
# 9

# %%
p_guess = int(input("Enter guessed number"))
count = 1
while (p_guess != number):
    if p_guess < 1 or p_guess > 100:
        print("OUT OF BOUNDS")
        p_guess = int(input("Enter guessed number"))
        continue
    diffVal = abs(p_guess - number)
    if (count==1):
        if diffVal <= 10:
            print("WARM!")
        else:
            print("COLD!")
    p_guess = int(input("Enter guessed number"))
    if abs(p_guess - number) < diffVal:
        print("WARMER!")
    else:
        print("COLDER!")
    
    count +=1
print("Guessed correctly in {} chances".format(count))
# Out:
# Enter guessed number 50
# COLD!
# Enter guessed number 25
# WARMER!
# Enter guessed number 40
# COLDER!
# Enter guessed number 30
# WARMER!
# Enter guessed number 37
# COLDER!
# Enter guessed number 27
# WARMER!
# Enter guessed number 25
# WARMER!
# Enter guessed number 23
# WARMER!
# Enter guessed number 20
# WARMER!
# Enter guessed number 15
# WARMER!
# Enter guessed number 5
# WARMER!
# Enter guessed number 2
# COLDER!
# Enter guessed number 3
# WARMER!
# Enter guessed number 4
# WARMER!
# Enter guessed number 7
# WARMER!
# Enter guessed number 9
# WARMER!
# Guessed correctly in 16 chances

# %%
# floatn = random() * 100
# floatn
# Out:
# 3.3666718613716506

# %% [markdown]
# ### Good Job!
